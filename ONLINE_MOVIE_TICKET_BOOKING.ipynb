# %% [markdown]
# <a href="https://colab.research.google.com/github/Kishan20023/Python_Projects/blob/main/ONLINE_MOVIE_TICKET_BOOKING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
global num
num= 0

# t_movie function is used to select movie name.

def t_movie():

  global num
  num = num+1
  # The list of movies.

  print("which movie do you want to watch?")
  print("1:ROOHI")
  print("2:KARNAN")
  print("3:VAKEEL SAAB")
  print("4:Back")

  movie = int(input("choose your movie: "))
  if movie == 4:
    print("Sorry! Go back to menu for booking ticket")
  if movie==1 or movie==2 or movie==3:
    if num == 1:
      theater()

# theater function used to select screen.

def theater():

  #List of screens.

    print("which screen do you want to watch movie: ")
    print("1:SCREEN 1")
    print("2:SCREEN 2")
    print("3:SCREEN 3")

    a = int(input("Choose your screen: "))

    # Giving input for number of tickets.

    ticket = int(input("Number of tickets do you want : "))

    # Giving timing for the movies.

    time={1:"10.00-1.00",2:"1.10-4.10",3:"4.20-7.20",4:"7.30-10.30"}

    print("Select your timing for the movie : ")
    print(time)
    t=int(input("Choose your time : "))
    x=time[t]

    # Printing the timing and ticket completion.

    print("Sucessfull!\nEnjoy Your Movie at ",x)
    print("Thank you!")

def movie(theater):

    if theater == 1:
        t_movie()
    elif theater == 2:
        t_movie()
    elif theater == 3:
        t_movie()
    else:
        print("Wrong choice! Please go back to the menu!")

  # List of centers.

def center():

    print("which theater do you wish to see movie? ")
    print("1:Inox")
    print("2:Icon")
    print("3:PVP")
    print("4:Back to the menu")
    a = int(input("choose your option: "))
    movie(a)

# this function is used to select city

def city():

  # List of cities.

    print("Hi! Welcome to movie ticket booking! ")
    print("Where you want to watch movie? : ")
    print("1:CHENNAI")
    print("2:NEW DELHI ")
    print("3:HYDERABAD ")

    place = int(input("choose your option: "))
    if place == 1:
      center()
    elif place == 2:
      center()
    elif place == 3:
      center()
    else:
      print("wrong choice")


city() # it calls the function city
# Out:
# Hi! Welcome to movie ticket booking!
# Where you want to watch movie? :
# 1:CHENNAI
# 2:NEW DELHI
# 3:HYDERABAD
# choose your option: 1
# which theater do you wish to see movie?
# 1:Inox
# 2:Icon
# 3:PVP
# 4:Back to the menu
# choose your option: 1
# which movie do you want to watch?
# 1:ROOHI
# 2:KARNAN
# 3:VAKEEL SAAB
# 4:Back
# choose your movie: 2
# which screen do you want to watch movie:
# 1:SCREEN 1
# 2:SCREEN 2
# 3:SCREEN 3
# Choose your screen: 3
# Number of tickets do you want : 6
# Select your timing for the movie :
# {1: '10.00-1.00', 2: '1.10-4.10', 3: '4.20-7.20', 4: '7.30-10.30'}
# Choose your time : 2
# Sucessfull!
# Enjoy Your Movie at  1.10-4.10
# Thank you!
